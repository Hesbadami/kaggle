# %%
import pandas as pd
import matplotlib.pyplot as plt
from utilities import gen_data
from forecaster import Forecaster

from sklearn.linear_model import Ridge
from xgboost import XGBRegressor

# %%
df = gen_data(100)

# %%
df.plot(x = 'ds', y = 'y', figsize = (15, 3))
# Out:
# <Axes: xlabel='ds'>

# %%
model = Forecaster(
    df,
    x = 'ds',
    y = 'y'
)
